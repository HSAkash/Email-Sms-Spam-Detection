# %% [markdown]
# # Import dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# For spliting dataset
from sklearn.model_selection import train_test_split

# For preprocessing data
import re
import nltk
import string
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# For building the model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Dense, Embedding, Dropout,
    GlobalAveragePooling1D, Input
)
from tensorflow.keras.models import Model

# %%
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## File path

# %%
data_path = "/kaggle/input/sms-spam-collection-dataset/spam.csv"

# %% [markdown]
# ## Read data from csv file

# %%
df = pd.read_csv(data_path, encoding='ISO-8859-1')
df = df[['v1', 'v2']]
df.columns = ['Category', 'Content']
df.head()
# Out:
#   Category                                            Content
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ## Understanding the distribution of ham and spam messages

# %%
plt.figure(figsize=(8, 6))
df.Category.value_counts().plot(kind='bar', color='green')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Text cleaner Fnction

# %%
stopwords = nltk.corpus.stopwords.words('english')
ps = nltk.PorterStemmer()

# %%
def clean_text(text):
    # Remove punctuation from text
    text = "".join([word.lower() for word in text if word not in string.punctuation])
    tokens = re.split('\W+', text)
    # Get Origin of words (books -> book)
    text = " ".join([ps.stem(word) for word in tokens if word not in stopwords])
    return text

# %% [markdown]
# ## Clean the text

# %%
df['Clean_text'] = df['Content'].apply(lambda x: clean_text(x))
df.head()
# Out:
#   Category                                            Content  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
#
#                                           Clean_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4          nah dont think goe usf live around though

# %% [markdown]
# ## Category column string to int8

# %%
# {ham:0, spam:1}
df['label'] = df['Category'].astype('category').cat.codes
df.head()
# Out:
#   Category                                            Content  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
#
#                                           Clean_text  label
# 0  go jurong point crazi avail bugi n great world...      0
# 1                              ok lar joke wif u oni      0
# 2  free entri 2 wkli comp win fa cup final tkt 21...      1
# 3                u dun say earli hor u c alreadi say      0
# 4          nah dont think goe usf live around though      0

# %% [markdown]
# ## Spliting data

# %%
X_train,X_test,y_train,y_test=train_test_split(
    df['Clean_text'],df['label'],test_size=0.25,random_state=SEED)

# %% [markdown]
# # Tokenize

# %% [markdown]
# ## Define the parameters

# %%
max_len=50 # max words in every input string
trunc_type='post' # if number of words are more than max_len then trunct from the last of the string
padding_type='post' # if number of words are less than max_len then add
oov_token_1='<OOV>'# out of vocabulary token
vocab_size=500

# %% [markdown]
# ## Text to numerical
# `
# Create a tokenizer and fit
# `

# %%
tokenizer=Tokenizer(num_words=vocab_size,char_level=False,oov_token=oov_token_1)
tokenizer.fit_on_texts(X_train)

# %%
print(f"Total token : {len(tokenizer.word_index)}")
for token_word in tokenizer.word_index:
    print(f"{token_word}: {tokenizer.word_index[token_word]}")
    if tokenizer.word_index[token_word] >10:
        break
# Out:
# Total token : 6851
# <OOV>: 1
# u: 2
# call: 3
# 2: 4
# im: 5
# go: 6
# get: 7
# ur: 8
# å: 9
# come: 10
# 4: 11

# %% [markdown]
# ## Tokenize and padding

# %%
X_train = tokenizer.texts_to_sequences(X_train)
X_train = pad_sequences(X_train,maxlen=max_len,padding=padding_type,truncating=trunc_type)

# %%
X_test=tokenizer.texts_to_sequences(X_test)
X_test=pad_sequences(X_test,maxlen=max_len,padding=padding_type,truncating=trunc_type)

# %%
X_train.shape, X_test.shape
# Out:
# ((4179, 50), (1393, 50))

# %% [markdown]
# # Modeling

# %%
input_shape = X_train.shape[1:]
input_shape
# Out:
# (50,)

# %%
input = Input(shape=input_shape)
x = Embedding(input_dim=vocab_size, output_dim=12)(input)
x = GlobalAveragePooling1D()(x)
x = Dense(24, activation='relu')(x)
x = Dropout(0.2)(x)
output = Dense(1, activation='sigmoid')(x)
model = Model(inputs=input, outputs=output)
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 50)]              0
#
#  embedding (Embedding)       (None, 50, 12)            6000
#
#  global_average_pooling1d (G  (None, 12)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 24)                312
#
#  dropout (Dropout)           (None, 24)                0
#
#  dense_1 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 6,337
# Trainable params: 6,337
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Plot the model

# %%
tf.keras.utils.plot_model(model)

# %% [markdown]
# ## Fit the model

# %%
num_epochs=50
# If val_loss increases five times it will stop model fitting
early_stop=EarlyStopping(monitor='val_loss',patience=5)
history=model.fit(
    X_train,
    y_train,
    epochs=num_epochs,
    validation_data=(X_test,y_test),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# 131/131 [==============================] - 2s 4ms/step - loss: 0.5533 - accuracy: 0.8653 - val_loss: 0.4005 - val_accuracy: 0.8629
# Epoch 2/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.3547 - accuracy: 0.8670 - val_loss: 0.3265 - val_accuracy: 0.8629
# Epoch 3/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.3081 - accuracy: 0.8670 - val_loss: 0.2824 - val_accuracy: 0.8629
# Epoch 4/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.2554 - accuracy: 0.8775 - val_loss: 0.2240 - val_accuracy: 0.9045
# Epoch 5/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.1982 - accuracy: 0.9273 - val_loss: 0.1769 - val_accuracy: 0.9354
# Epoch 6/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.1573 - accuracy: 0.9495 - val_loss: 0.1470 - val_accuracy: 0.9505
# Epoch 7/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.1317 - accuracy: 0.9591 - val_loss: 0.1269 - val_accuracy: 0.9569
# Epoch 8/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.1123 - accuracy: 0.9639 - val_loss: 0.1087 - val_accuracy: 0.9648
# Epoch 9/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0957 - accuracy: 0.9684 - val_loss: 0.0967 - val_accuracy: 0.9670
# Epoch 10/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0823 - accuracy: 0.9732 - val_loss: 0.0892 - val_accuracy: 0.9684
# Epoch 11/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0741 - accuracy: 0.9773 - val_loss: 0.0827 - val_accuracy: 0.9734
# Epoch 12/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 0.9804 - val_loss: 0.0785 - val_accuracy: 0.9742
# Epoch 13/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0611 - accuracy: 0.9832 - val_loss: 0.0792 - val_accuracy: 0.9734
# Epoch 14/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0581 - accuracy: 0.9828 - val_loss: 0.0748 - val_accuracy: 0.9749
# Epoch 15/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0508 - accuracy: 0.9866 - val_loss: 0.0717 - val_accuracy: 0.9770
# Epoch 16/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0491 - accuracy: 0.9856 - val_loss: 0.0732 - val_accuracy: 0.9749
# Epoch 17/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0476 - accuracy: 0.9864 - val_loss: 0.0710 - val_accuracy: 0.9770
# Epoch 18/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0428 - accuracy: 0.9895 - val_loss: 0.0702 - val_accuracy: 0.9770
# Epoch 19/50
# 131/131 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 0.9868 - val_loss: 0.0686 - val_accuracy: 0.9799
# Epoch 20/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0401 - accuracy: 0.9895 - val_loss: 0.0685 - val_accuracy: 0.9806
# Epoch 21/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0380 - accuracy: 0.9902 - val_loss: 0.0703 - val_accuracy: 0.9770
# Epoch 22/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0359 - accuracy: 0.9895 - val_loss: 0.0703 - val_accuracy: 0.9799
# Epoch 23/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0340 - accuracy: 0.9897 - val_loss: 0.0688 - val_accuracy: 0.9799
# Epoch 24/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9904 - val_loss: 0.0720 - val_accuracy: 0.9799
# Epoch 25/50
# 131/131 [==============================] - 0s 3ms/step - loss: 0.0333 - accuracy: 0.9902 - val_loss: 0.0706 - val_accuracy: 0.9792

# %% [markdown]
# ## Evaluate

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 0.0706 - accuracy: 0.9792
# [0.07056508958339691, 0.9791816473007202]

# %% [markdown]
# ## plot_loss_curves

# %%
def plot_loss_curves(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
plot_loss_curves(history)
